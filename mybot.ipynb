# %% [markdown]
# AI Assistant Chatbot Development

# %%
import ollama

# %%
response = ollama.chat(
    model = 'mistral',
    messages=[
        {
            'role' : 'user',
            'content' : 'what is deep learning?'
        }
    ]
)

print(response['message']['content'])
# Out:
#  Deep Learning is a subset of machine learning that focuses on training artificial neural networks with multiple layers to learn and make decisions automatically. These models can learn complex patterns by processing large amounts of data, similar to the way the human brain works. They are particularly useful for tasks like image recognition, speech recognition, natural language processing, and predictive analytics. Deep Learning has revolutionized various industries, including healthcare, finance, self-driving cars, and more. It's important to note that deep learning requires a substantial amount of data and computational power.

# %%
user_input = input("Ask question...")

response = ollama.chat(
    model = 'mistral',
    messages=[
        {
            'role' : 'user',
            'content' : user_input
        }
    ]
)

print(response['message']['content'])
# Out:
#  The capital of India is New Delhi. It serves as the political and administrative center, housing important institutions such as the Parliament of India and the Presidential Palace. Delhi is one of India's largest cities, and it consists of multiple districts, including New Delhi, which was designed and built by British architects Sir Edwin Lutyens and Sir Herbert Baker in 1911-1931.

# %%
def ask_ai(question):
    response = ollama.chat(
    model = 'mistral',
    messages=[
            {
            'role' : 'user',
            'content' : question
            }
        ]
    )
    return response['message']['content']

# %%
def gym_trainer(question):
    response = ollama.chat(
        model = 'mistral',
        messages=[
            {
                'role' : 'system',
                'content' : """ You are a gym trainer. 
                rules:
                    - Be polite and friendly
                    - keep answers short and to the point
                    - give diet plan for weigt loss
                """
            },
            {
                'role' : 'user',
                'content' : question
            }
        ]
    )
    return response['message']['content']

# %%
gym_trainer("i want a diet plan to lose weight")
# Out:
# " I'm glad you're taking steps towards a healthier lifestyle! Here's a simple diet plan to help with weight loss:\n\n1. **Balance Your Plate**: Aim for half of your plate to be non-starchy vegetables (like spinach, broccoli, and peppers), one quarter lean proteins (chicken, fish, or beans), and the other quarter whole grains (brown rice or quinoa).\n\n2. **Portion Control**: Pay attention to portion sizes to avoid overeating. Use smaller plates for visual cues of appropriate serving sizes.\n\n3. **Healthy Fats**: Include healthy fats like avocados, nuts, seeds, and olive oil in your diet. They can help you feel full and satisfied.\n\n4. **Limit Processed Foods and Sugars**: Try to minimize intake of processed foods, sugary drinks, and high-calorie snacks. These foods often contain a lot of empty calories that don't contribute to feeling full.\n\n5. **Hydration**: Stay hydrated by drinking plenty of water throughout the day. Aim for at least 8 glasses per day.\n\n6. **Regular Meals**: Eat three main meals and two healthy snacks each day. This will keep your metabolism active and prevent overeating."
